# %% [markdown]
# DATA VISUALIZATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('toyota.csv')

# %%
df
# Out:
#      Price  Age      Km FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0    20795    5   97958   Petrol   71         1          0  1405      3
# 1     5860    7  150937   Diesel  139         1          1  1231      5
# 2    10390    9  143291   Diesel   86         1          1  1532      3
# 3    16964    7   49809   Diesel   97         1          0  1818      2
# 4    16284   13  126748      CNG  135         1          0  1549      5
# ..     ...  ...     ...      ...  ...       ...        ...   ...    ...
# 495  10486    6  156389   Diesel  132         1          0  1725      3
# 496  13335    2  125608   Petrol   90         1          0  1682      2
# 497   9491    8   17564      CNG  121         1          1  1834      3
# 498  16130   10  168417   Diesel  124         0          1  1565      2
# 499  12651    5  123824      CNG   95         0          0  1905      3
#
#      Weight
# 0      1193
# 1      1473
# 2      1497
# 3      1345
# 4      1109
# ..      ...
# 495    1213
# 496    1060
# 497    1230
# 498    1427
# 499    1237
#
# [500 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Price        0
# Age          0
# Km           0
# FuelType     0
# HP           0
# MetColor     0
# Automatic    0
# CC           0
# Doors        0
# Weight       0
# dtype: int64

# %%
df=df.dropna(axis=1)

# %%
df
# Out:
#      Price  Age      Km FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0    20795    5   97958   Petrol   71         1          0  1405      3
# 1     5860    7  150937   Diesel  139         1          1  1231      5
# 2    10390    9  143291   Diesel   86         1          1  1532      3
# 3    16964    7   49809   Diesel   97         1          0  1818      2
# 4    16284   13  126748      CNG  135         1          0  1549      5
# ..     ...  ...     ...      ...  ...       ...        ...   ...    ...
# 495  10486    6  156389   Diesel  132         1          0  1725      3
# 496  13335    2  125608   Petrol   90         1          0  1682      2
# 497   9491    8   17564      CNG  121         1          1  1834      3
# 498  16130   10  168417   Diesel  124         0          1  1565      2
# 499  12651    5  123824      CNG   95         0          0  1905      3
#
#      Weight
# 0      1193
# 1      1473
# 2      1497
# 3      1345
# 4      1109
# ..      ...
# 495    1213
# 496    1060
# 497    1230
# 498    1427
# 499    1237
#
# [500 rows x 10 columns]

# %%
plt.scatter(x=df['Age'],y=df['Price'],c="red")
plt.title="scaltter plot of price vs age"
plt.show()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Price  Age      Km FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0    20795    5   97958   Petrol   71         1          0  1405      3
# 1     5860    7  150937   Diesel  139         1          1  1231      5
# 2    10390    9  143291   Diesel   86         1          1  1532      3
# 3    16964    7   49809   Diesel   97         1          0  1818      2
# 4    16284   13  126748      CNG  135         1          0  1549      5
# ..     ...  ...     ...      ...  ...       ...        ...   ...    ...
# 495  10486    6  156389   Diesel  132         1          0  1725      3
# 496  13335    2  125608   Petrol   90         1          0  1682      2
# 497   9491    8   17564      CNG  121         1          1  1834      3
# 498  16130   10  168417   Diesel  124         0          1  1565      2
# 499  12651    5  123824      CNG   95         0          0  1905      3
#
#      Weight
# 0      1193
# 1      1473
# 2      1497
# 3      1345
# 4      1109
# ..      ...
# 495    1213
# 496    1060
# 497    1230
# 498    1427
# 499    1237
#
# [500 rows x 10 columns]>

# %% [markdown]
# HISTOGRAM

# %%
plt.hist(df['Km'],color='red',edgecolor='white')
plt.title='Histogram of Km'
plt.show()

# %%
counts=[979,120,12]
fuelType=('Petrol','CNG','Diesel')
index=np.arange(len(fuelType))
plt.bar(index,counts,color=['red','blue','cyan'])
plt.show()

# %%
plt.scatter(df['Age'],df['Price'],df['MetColor'])
plt.colorbar()
plt.show()

# %%
plt.plot(df['Age'])
plt.plot(df['Price'])
plt.show()
